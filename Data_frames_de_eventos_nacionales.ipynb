# %% [markdown]
# # Registro de eventos nacionales

# %% [markdown]
# En el siguiente data frame podemos observar el registro de eventos que se realizaron en los periodos del 2018 al 2023, en el cual se mencionan datos importantes como el tipo de evento, la fecha en la que se realizará, el lugar en donde se llevará a cabo, etc.

# %%
import pandas as pd

# %%
Eventos_culturales_2018_2023 = pd.read_csv("C:/Users/ferna/OneDrive/Escritorio/TRABAJO_FINAL_LP2/Web-Scraping-de-diversos-eventos-en-el-Per-/DATASET-EVENTOS-CULTURALES-2018-2022 (1).csv", delimiter=';')
Eventos_culturales_2018_2022.head(10) # Para obtener las 10 primeras filas del data frame
# Out:
#    FECHACORTE                                      TITULO_EVENTO  \
# 0    20230919                   Cuentos breves y extraordinarios
# 1    20230919            Diviértete con los juegos tradicionales
# 2    20230919  Elaboremos nuestros animales favoritos en Origami
# 3    20230919               Manualidades con material reciclable
# 4    20230919                         Ajedrez para principiantes
# 5    20230919                                Aprendiendo origami
# 6    20230919                           Canva para principiantes
# 7    20230919                  Microsoft Word para principiantes
# 8    20230919                   Juega creando animales con papel
# 9    20230919                                  Manitos creativas
#
#           CATEGORIA  FECHA_INICIO_EVENTO  FECHA_FIN_EVENTO   TIPO_INGRESO  \
# 0  Taller y/o curso             20230121          20230121  Ingreso Libre
# 1  Taller y/o curso             20230113          20230120  Ingreso Libre
# 2  Taller y/o curso             20230119          20230119  Ingreso Libre
# 3  Taller y/o curso             20230119          20230126  Ingreso Libre
# 4  Taller y/o curso             20230119          20230126  Ingreso Libre
# 5  Taller y/o curso             20230118          20230125  Ingreso Libre
# 6  Taller y/o curso             20230117          20230124  Ingreso Libre
# 7  Taller y/o curso             20230113          20230127  Ingreso Libre
# 8  Taller y/o curso             20230112          20230126  Ingreso Libre
# 9  Taller y/o curso             20230111          20230127  Ingreso Libre
#
#                UBICACION  FECHA_PUBLICACION_EVENTO TIPO_EVENTO  \
# 0  Hall de Intelectuales                  20221227  Presencial
# 1                   Sala                  20221227  Presencial
# 2                   Sala                  20221227  Presencial
# 3                   Sala                  20221227  Presencial
# 4                   Sala                  20221227  Presencial
# 5                   Sala                  20221227  Presencial
# 6                   Sala                  20221227  Presencial
# 7                   Sala                  20221227  Presencial
# 8                   Sala                  20221227  Presencial
# 9          Sala Infantil                  20221227  Presencial
#
#                                            SEDE
# 0               Gran Biblioteca Pública de Lima
# 1        Estación de Biblioteca Pública - Rímac
# 2        Estación de Biblioteca Pública - Breña
# 3        Estación de Biblioteca Pública - Rímac
# 4  Estación de Biblioteca Pública - La Victoria
# 5        Estación de Biblioteca Pública - Rímac
# 6  Estación de Biblioteca Pública - La Victoria
# 7  Estación de Biblioteca Pública - El Agustino
# 8  Estación de Biblioteca Pública - El Agustino
# 9               Gran Biblioteca Pública de Lima

# %%
Eventos_culturales_2018_2022['CATEGORIA'].unique() 

# Observamos que los dintitos tipos de categoria son :
# Out:
# array(['Taller y/o curso', 'Presentación de publicación',
#        'Charla, conversatorio y/o conferencia', 'Mediación de lectura',
#        'Club de lectura', 'Exposición', 'Narración oral',
#        'Cinefórum y/o proyección de cine', 'Otros', 'Teatro para adultos',
#        'Teatro para niños', 'Conciertos'], dtype=object)

# %%
Eventos_culturales_2018_2022['TIPO_INGRESO'].unique()

# Hay 3 tipos de ingreso:
# Out:
# array(['Ingreso Libre', 'Inscripcion', 'Venta'], dtype=object)

# %%
Eventos_culturales_2018_2022['TIPO_EVENTO'].unique()
# Dos tipo de modalidad de los eventos:
# Out:
# array(['Presencial', 'Virtual'], dtype=object)

# %% [markdown]
# En el siguiente data frame que veremos a continuación, tenemos solo el registro del primer semestre del 2023. Aqui tambien se nos proporciona información como fecha en la que se realizó el evento, ubicación, categoria,tipo de evento, ya sea presencial o virtual,etc.

# %%
Eventos_culturales_2023_I_semestre = pd.read_csv("C:/Users/ferna/OneDrive/Escritorio/TRABAJO_FINAL_LP2/Web-Scraping-de-diversos-eventos-en-el-Per-/DATASET-EVENTOS-CULTURALES-I-SEMESTRE-2023.csv", delimiter=';')
Eventos_culturales_2023_I_semestre
# Out:
#      FECHACORTE                                      TITULO_EVENTO  \
# 0      20230919                                Cazadores de libros
# 1      20230919              Elaborando mi propio huaco de arcilla
# 2      20230919    Importancia del Qhapaq Ñan: sistema vial andino
# 3      20230919  Montaje de teatro de títeres del cuento "Claud...
# 4      20230919                           Reusamos y nos recreamos
# ..          ...                                                ...
# 245    20230919                        Aprende matemáticas jugando
# 246    20230919                                Tejiendo mis sueños
# 247    20230919                      Conociendo el sistema Braille
# 248    20230919                    Explorando el mundo del origami
# 249    20230919                                 Ajedrez: Ludichess
#
#             CATEGORIA  FECHA_INICIO_EVENTO  FECHA_FIN_EVENTO   TIPO_INGRESO  \
# 0     Club de lectura             20230704          20230711  Ingreso Libre
# 1    Taller y/o curso             20230721          20230721  Ingreso Libre
# 2    Taller y/o curso             20230714          20230714  Ingreso Libre
# 3    Taller y/o curso             20230713          20230714  Ingreso Libre
# 4    Taller y/o curso             20230711          20230721  Ingreso Libre
# ..                ...                  ...               ...            ...
# 245  Taller y/o curso             20230120          20230127  Ingreso Libre
# 246  Taller y/o curso             20230120          20230127  Ingreso Libre
# 247  Taller y/o curso             20230119          20230126  Ingreso Libre
# 248  Taller y/o curso             20230117          20230124  Ingreso Libre
# 249  Taller y/o curso             20230103          20230209  Ingreso Libre
#
#                 UBICACION  FECHA_PUBLICACION_EVENTO TIPO_EVENTO  \
# 0                    Sala                  20230628  Presencial
# 1          Sala Principal                  20230628  Presencial
# 2    Sala para Invidentes                  20230628  Presencial
# 3          Sala Principal                  20230628  Presencial
# 4          Sala Principal                  20230628  Presencial
# ..                    ...                       ...         ...
# 245                  Sala                  20230105  Presencial
# 246                  Sala                  20230105  Presencial
# 247                  Sala                  20230105  Presencial
# 248                  Sala                  20230104  Presencial
# 249          Sala Escolar                  20230103  Presencial
#
#                                                  SEDE
# 0        Estación de Biblioteca Pública - La Victoria
# 1         Estación de Biblioteca Pública Tarata-Tacna
# 2                     Gran Biblioteca Pública de Lima
# 3         Estación de Biblioteca Pública Tarata-Tacna
# 4    Estación de Biblioteca Pública Cutervo-Cajamarca
# ..                                                ...
# 245            Estación de Biblioteca Pública - Comas
# 246            Estación de Biblioteca Pública - Comas
# 247      Estación de Biblioteca Pública - El Agustino
# 248            Estación de Biblioteca Pública - Comas
# 249                   Gran Biblioteca Pública de Lima
#
# [250 rows x 10 columns]
