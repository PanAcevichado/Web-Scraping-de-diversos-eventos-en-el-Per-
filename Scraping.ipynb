# %%
#Paquetes
import requests
import bs4 as bs
import pandas as pd
import re
# !pip install prettytable
# Out:
# Collecting prettytable
#   Obtaining dependency information for prettytable from https://files.pythonhosted.org/packages/4d/81/316b6a55a0d1f327d04cc7b0ba9d04058cb62de6c3a4d4b0df280cbe3b0b/prettytable-3.9.0-py3-none-any.whl.metadata
#   Downloading prettytable-3.9.0-py3-none-any.whl.metadata (26 kB)
# Requirement already satisfied: wcwidth in c:\users\ferna\anaconda3\lib\site-packages (from prettytable) (0.2.5)
# Downloading prettytable-3.9.0-py3-none-any.whl (27 kB)
# Installing collected packages: prettytable
# Successfully installed prettytable-3.9.0

# %%
#Joinnus

url = "https://www.joinnus.com/search?searchKey={%22text%22:%22%22,%22maps%22:false,%22filters%22:{%22price%22:{%22min%22:%22%22,%22max%22:%22%22},%22categories%22:[%22stand-up%22,%22concerts%22,%22theater%22,%22art-culture%22],%22dates%22:{%22key%22:%22all%22,%22dateStart%22:%222024-01-05T10:32:09%22,%22dateEnd%22:%222024-01-05T23:59:00%22},%22location%22:{%22z%22:12,%22center%22:{%22lat%22:-12.074317294768308,%22lng%22:-77.04348643769534}},%22city%22:[]},%22page%22:1,%22country%22:%22PE%22}"
response = requests.get(url)
content = response.text
content
# Out:
# '<!DOCTYPE html><html lang="es"><head><base href="/"/><link rel="dns-prefetch" href="//fonts.googleapis.com"/><link rel="dns-prefetch" href=""/><link rel="dns-prefetch" href="https://cdn.joinnus.com"/><meta name="facebook-domain-verification" content="ub9cq5n8pnrvydhpr7m816c3ule140"/><meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=1.0,user-scalable=no,minimal-ui"/><link href="/static/favicons/favicon.ico" rel="shortcut icon" type="image/vnd.microsoft.icon"/><link href="/static/favicons/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/><link href="/static/favicons/favicon-32x32.png" rel="icon" type="image/png" sizes="32x32"/><link href="/static/favicons/favicon-16x16.png" rel="icon" type="image/png" sizes="16x16"/><meta name="theme-color" content="#00000"/><link rel="manifest" href="static/manifest.json"/><link rel="stylesheet" data-href="https://fonts.googleapis.com/css?family=Material+Icons|Roboto:300,400,500,700|Poppins:300,400,500,600,700,800,900|Montserrat:300,400,600,700|Questrial"/><link rel="stylesheet" data-href="https://fonts.googleapis.com/css2?family=Baloo+2:wght@400;500;700&amp;display=swap"/><link rel="stylesheet" type="text/css" href="/_next/static/styles/joinnus.1824fb8.css"/><script defer="" src="https://api.joinnus.com/v1/jsonip?callback=getIP"></script><script>\n(function(w,d,s,l,i){\nw[l]=w[l]||[];\nw[l].push({\'gtm.start\':new Date().getTime(),event:\'gtm.js\'});\nvar f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';\nj.async=true;j.src=\'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\n})(window,document,\'script\',\'dataLayer\',\'GTM-PZLTD9\');\n</script><script async="" defer="" src="https://connect.facebook.net/es_LA/sdk.js"></script><script>\nvar config = {"lang":"es","country":"PE","brandCode":"joinnus","appUrl":"https://www.joinnus.com","layoutTpl":"joinnus","baseUrl":"https://www.joinnus.com"};\nvar lang = "es";\nvar country = "PE";\nvar brandCode = "joinnus";\nvar layoutTpl = "joinnus";\nvar userIp = \'\';\nfunction getIP(json) {\n  userIp = json.ip;\n}\n</script><meta name="viewport" content="width=device-width"/><meta charSet="utf-8"/><title>Encuentra eventos, lugares, organizadores y más</title><meta name="description" content="Descubre todos los eventos que tu ciudad tiene para ti! Conciertos, festivales, fiestas, conferencias y más."/><meta name="twitter:card" content="summary"/><meta name="twitter:site" content="@joinnus"/><meta name="twitter:title" content="Encuentra eventos, lugares, organizadores y más"/><meta name="twitter:description" content="Descubre todos los eventos que tu ciudad tiene para ti! Conciertos, festivales, fiestas, conferencias y más."/><meta name="twitter:creator" content="@joinnus"/><meta name="twitter:image" content="https://cdn.joinnus.com/files/share-twitter.jpg"/><meta property="og:title" content="Encuentra eventos, lugares, organizadores y más"/><meta property="og:type" content="website"/><meta property="og:url" content="https://www.joinnus.com/search?searchKey=%7B%22text%22%3A%22%22%2C%22maps%22%3Afalse%2C%22filters%22%3A%7B%22price%22%3A%7B%22min%22%3A%22%22%2C%22max%22%3A%22%22%7D%2C%22categories%22%3A%5B%22stand-up%22%2C%22concerts%22%2C%22theater%22%2C%22art-culture%22%5D%2C%22dates%22%3A%7B%22key%22%3A%22all%22%2C%22dateStart%22%3A%222024-01-05T10%3A32%3A09%22%2C%22dateEnd%22%3A%222024-01-05T23%3A59%3A00%22%7D%2C%22location%22%3A%7B%22z%22%3A12%2C%22center%22%3A%7B%22lat%22%3A-12.074317294768308%2C%22lng%22%3A-77.04348643769534%7D%7D%2C%22city%22%3A%5B%5D%7D%2C%22page%22%3A1%2C%22country%22%3A%22PE%22%7D"/><meta property="og:image" content="https://cdn.joinnus.com/files/share-facebook.jpg"/><meta property="og:description" content="Descubre todos los eventos que tu ciudad tiene para ti! Conciertos, festivales, fiestas, conferencias y más."/><meta property="og:site_name" content="Joinnus.com"/><meta property="fb:admins" content="465516883516823 ...

# %%
#Kandavu

url = "https://www.kandavu.com/"
response = requests.get(url)
content = response.text
# Out:
# '<!DOCTYPE html>\n<html>\n<head>\n\t<meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />\n\t<meta name="author" content="Kandavu">\n\t<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n\t<meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1" >\n\t<link rel="stylesheet" type="text/css" href="https://www.kandavu.com/wp-content/themes/wp-theme-kandavu/assets/css/normalize.css?ver=2.8" />\n\t<!-- create blog -->\n\t<link rel="stylesheet" type="text/css" href="https://www.kandavu.com/wp-content/themes/wp-theme-kandavu/assets/css/main.css?ver=2.6" />\n\t<!-- css pages -->\n\t<!-- <link rel="stylesheet" type="text/css" href="/assets/css/styles.css?ver=2.8" /> -->\n\t<title>Inicio - Kandavu</title>\n\n<!-- This site is optimized with the Yoast SEO plugin v13.2 - https://yoast.com/wordpress/plugins/seo/ -->\n<meta name="robots" content="max-snippet:-1, max-image-preview:large, max-video-preview:-1"/>\n<link rel="canonical" href="https://www.kandavu.com/" />\n<meta property="og:locale" content="es_ES" />\n<meta property="og:type" content="website" />\n<meta property="og:title" content="Inicio - Kandavu" />\n<meta property="og:url" content="https://www.kandavu.com/" />\n<meta property="og:site_name" content="Kandavu" />\n<meta property="og:image" content="https://www.kandavu.com/wp-content/uploads/2019/12/kandavu-fb.jpg" />\n<meta property="og:image:secure_url" content="https://www.kandavu.com/wp-content/uploads/2019/12/kandavu-fb.jpg" />\n<meta property="og:image:width" content="520" />\n<meta property="og:image:height" content="275" />\n<meta name="twitter:card" content="summary_large_image" />\n<meta name="twitter:title" content="Inicio - Kandavu" />\n<meta name="twitter:image" content="https://www.kandavu.com/wp-content/uploads/2019/12/kandavu-fb.jpg" />\n<script type=\'application/ld+json\' class=\'yoast-schema-graph yoast-schema-graph--main\'>{"@context":"https://schema.org","@graph":[{"@type":"WebSite","@id":"https://www.kandavu.com/#website","url":"https://www.kandavu.com/","name":"Kandavu","inLanguage":"es","potentialAction":{"@type":"SearchAction","target":"https://www.kandavu.com/?s={search_term_string}","query-input":"required name=search_term_string"}},{"@type":"ImageObject","@id":"https://www.kandavu.com/#primaryimage","inLanguage":"es","url":"https://www.kandavu.com/wp-content/uploads/2019/12/kandavu-fb.jpg","width":520,"height":275},{"@type":"WebPage","@id":"https://www.kandavu.com/#webpage","url":"https://www.kandavu.com/","name":"Inicio - Kandavu","isPartOf":{"@id":"https://www.kandavu.com/#website"},"inLanguage":"es","primaryImageOfPage":{"@id":"https://www.kandavu.com/#primaryimage"},"datePublished":"2019-01-04T15:59:09+00:00","dateModified":"2020-04-28T20:04:58+00:00"}]}</script>\n<!-- / Yoast SEO plugin. -->\n\n<link rel=\'dns-prefetch\' href=\'//s.w.org\' />\n<link rel=\'stylesheet\' id=\'wp-block-library-css\'  href=\'https://www.kandavu.com/wp-includes/css/dist/block-library/style.min.css?ver=5.3.16\' type=\'text/css\' media=\'all\' />\n<link rel=\'stylesheet\' id=\'wp-pagenavi-css\'  href=\'https://www.kandavu.com/wp-content/plugins/wp-pagenavi/pagenavi-css.css?ver=2.70\' type=\'text/css\' media=\'all\' />\n<link rel=\'stylesheet\' id=\'swiper-css-css\'  href=\'https://www.kandavu.com/wp-content/themes/wp-theme-kandavu/assets/js/swiper/swiper.min.css?ver=1.0\' type=\'text/css\' media=\'all\' />\n<link rel=\'stylesheet\' id=\'slick-css-css\'  href=\'https://www.kandavu.com/wp-content/themes/wp-theme-kandavu/assets/js/slick/slick.min.css?ver=1.0\' type=\'text/css\' media=\'all\' />\n<link rel=\'stylesheet\' id=\'boxlight-css-css\'  href=\'https://www.kandavu.com/wp-content/themes/wp-theme-kandavu/assets/js/boxlight/boxlight.min.css?ver=1.0\' type=\'text/css\' media=\'all\' />\n<link rel=\'stylesheet\' id=\'owl-css-css\'  href=\'https://www.kandavu.com/wp-content/themes/wp-theme-kandavu/assets/js/OwlCarousel2/owl.carousel.min.css?ver=1.0\' type=\'text/css\ ...

# %%
#Move concerts

url = "https://moveconcerts.com/pe/calendario/"
response = requests.get(url)
content = response.text

# %%
# Teleticket

url = "https://teleticket.com.pe/todos"
response = requests.get(url)
content = response.text
soup = bs.BeautifulSoup(content, 'lxml')

box = soup.find_all('div', {class_ := 'evento--box'})

# Extraemos el nombre de cada concierto, evento o tour

names = soup.find_all('h3')

nombres = [h3.text.strip() for h3 in names]

nombres.pop() # Eliminamos el último vlaor ya que no es un nombre sino se refiere a las 'cookies de la página

# Extraemos el lugar y el tipo del evento

site_class = soup.find_all('p', class_ = 'descripcion')

sitio_clasevento = [p.text.strip() for p in site_class]

# Separamos la lista en dos para una mejor visualización

Locacion = []
Tipo_de_evento = []

for elemento in sitio_clasevento:
    # Dividir el elemento usando "/" como separador
    partes = elemento.split('/')
    
    # Eliminar espacios en blanco alrededor de cada parte
    partes = [parte.strip() for parte in partes]

    # Almacenar las partes en las listas correspondientes
    Locacion.append(partes[0])
    Tipo_de_evento.append(partes[1])

# Extraemos las fechas

dates = soup.find_all('p', class_ = 'fecha')

fechas = [p.text.strip() for p in dates]

# De la lista Locacion extraemos el local, distrito, provincia

parte1 = []
parte2 = []
parte3 = []

for elemento in Locacion:
    # Dividir el elemento usando "-" como separador
    partes = elemento.split('-')
    
    # Eliminar espacios en blanco alrededor de cada parte
    partes = [parte.strip() for parte in partes]

    # Almacenar las partes en las listas correspondientes
    parte1.append(partes[0] if len(partes) > 0 else "")
    parte2.append(partes[1] if len(partes) > 1 else "")
    parte3.append(partes[2] if len(partes) > 2 else "")

lista_combinada = [f'{x}-{y}' for x, y in zip(parte2, parte3)]


data = { 'Nombre':nombres, 'Local':parte1, 'Zona':lista_combinada, 'Tipo de evento':Tipo_de_evento, 'Fecha': fechas}
df = pd.DataFrame(data)

# Función para centrar el texto en el cuerpo y el encabezado
def centrar_texto(val):
    return 'text-align: center'

# Aplicar la función al cuerpo del DataFrame
df_estilizado = df.style.applymap(centrar_texto)

# Función para centrar el encabezado
def centrar_encabezado(s):
    return 'text-align: center'

# Aplicar la función al encabezado del DataFrame
estilos = [dict(selector="th", props=[('text-align', 'center')])]

# Combinar estilos del cuerpo y del encabezado
df = df_estilizado.set_table_styles(estilos)

df
# Out:
# <style type="text/css">
# #T_e3c03 th {
#   text-align: center;
# }
# #T_e3c03_row0_col0, #T_e3c03_row0_col1, #T_e3c03_row0_col2, #T_e3c03_row0_col3, #T_e3c03_row0_col4, #T_e3c03_row1_col0, #T_e3c03_row1_col1, #T_e3c03_row1_col2, #T_e3c03_row1_col3, #T_e3c03_row1_col4, #T_e3c03_row2_col0, #T_e3c03_row2_col1, #T_e3c03_row2_col2, #T_e3c03_row2_col3, #T_e3c03_row2_col4, #T_e3c03_row3_col0, #T_e3c03_row3_col1, #T_e3c03_row3_col2, #T_e3c03_row3_col3, #T_e3c03_row3_col4, #T_e3c03_row4_col0, #T_e3c03_row4_col1, #T_e3c03_row4_col2, #T_e3c03_row4_col3, #T_e3c03_row4_col4, #T_e3c03_row5_col0, #T_e3c03_row5_col1, #T_e3c03_row5_col2, #T_e3c03_row5_col3, #T_e3c03_row5_col4, #T_e3c03_row6_col0, #T_e3c03_row6_col1, #T_e3c03_row6_col2, #T_e3c03_row6_col3, #T_e3c03_row6_col4, #T_e3c03_row7_col0, #T_e3c03_row7_col1, #T_e3c03_row7_col2, #T_e3c03_row7_col3, #T_e3c03_row7_col4, #T_e3c03_row8_col0, #T_e3c03_row8_col1, #T_e3c03_row8_col2, #T_e3c03_row8_col3, #T_e3c03_row8_col4, #T_e3c03_row9_col0, #T_e3c03_row9_col1, #T_e3c03_row9_col2, #T_e3c03_row9_col3, #T_e3c03_row9_col4, #T_e3c03_row10_col0, #T_e3c03_row10_col1, #T_e3c03_row10_col2, #T_e3c03_row10_col3, #T_e3c03_row10_col4, #T_e3c03_row11_col0, #T_e3c03_row11_col1, #T_e3c03_row11_col2, #T_e3c03_row11_col3, #T_e3c03_row11_col4, #T_e3c03_row12_col0, #T_e3c03_row12_col1, #T_e3c03_row12_col2, #T_e3c03_row12_col3, #T_e3c03_row12_col4, #T_e3c03_row13_col0, #T_e3c03_row13_col1, #T_e3c03_row13_col2, #T_e3c03_row13_col3, #T_e3c03_row13_col4, #T_e3c03_row14_col0, #T_e3c03_row14_col1, #T_e3c03_row14_col2, #T_e3c03_row14_col3, #T_e3c03_row14_col4, #T_e3c03_row15_col0, #T_e3c03_row15_col1, #T_e3c03_row15_col2, #T_e3c03_row15_col3, #T_e3c03_row15_col4, #T_e3c03_row16_col0, #T_e3c03_row16_col1, #T_e3c03_row16_col2, #T_e3c03_row16_col3, #T_e3c03_row16_col4, #T_e3c03_row17_col0, #T_e3c03_row17_col1, #T_e3c03_row17_col2, #T_e3c03_row17_col3, #T_e3c03_row17_col4, #T_e3c03_row18_col0, #T_e3c03_row18_col1, #T_e3c03_row18_col2, #T_e3c03_row18_col3, #T_e3c03_row18_col4, #T_e3c03_row19_col0, #T_e3c03_row19_col1, #T_e3c03_row19_col2, #T_e3c03_row19_col3, #T_e3c03_row19_col4, #T_e3c03_row20_col0, #T_e3c03_row20_col1, #T_e3c03_row20_col2, #T_e3c03_row20_col3, #T_e3c03_row20_col4, #T_e3c03_row21_col0, #T_e3c03_row21_col1, #T_e3c03_row21_col2, #T_e3c03_row21_col3, #T_e3c03_row21_col4, #T_e3c03_row22_col0, #T_e3c03_row22_col1, #T_e3c03_row22_col2, #T_e3c03_row22_col3, #T_e3c03_row22_col4, #T_e3c03_row23_col0, #T_e3c03_row23_col1, #T_e3c03_row23_col2, #T_e3c03_row23_col3, #T_e3c03_row23_col4, #T_e3c03_row24_col0, #T_e3c03_row24_col1, #T_e3c03_row24_col2, #T_e3c03_row24_col3, #T_e3c03_row24_col4, #T_e3c03_row25_col0, #T_e3c03_row25_col1, #T_e3c03_row25_col2, #T_e3c03_row25_col3, #T_e3c03_row25_col4, #T_e3c03_row26_col0, #T_e3c03_row26_col1, #T_e3c03_row26_col2, #T_e3c03_row26_col3, #T_e3c03_row26_col4, #T_e3c03_row27_col0, #T_e3c03_row27_col1, #T_e3c03_row27_col2, #T_e3c03_row27_col3, #T_e3c03_row27_col4, #T_e3c03_row28_col0, #T_e3c03_row28_col1, #T_e3c03_row28_col2, #T_e3c03_row28_col3, #T_e3c03_row28_col4, #T_e3c03_row29_col0, #T_e3c03_row29_col1, #T_e3c03_row29_col2, #T_e3c03_row29_col3, #T_e3c03_row29_col4, #T_e3c03_row30_col0, #T_e3c03_row30_col1, #T_e3c03_row30_col2, #T_e3c03_row30_col3, #T_e3c03_row30_col4, #T_e3c03_row31_col0, #T_e3c03_row31_col1, #T_e3c03_row31_col2, #T_e3c03_row31_col3, #T_e3c03_row31_col4, #T_e3c03_row32_col0, #T_e3c03_row32_col1, #T_e3c03_row32_col2, #T_e3c03_row32_col3, #T_e3c03_row32_col4, #T_e3c03_row33_col0, #T_e3c03_row33_col1, #T_e3c03_row33_col2, #T_e3c03_row33_col3, #T_e3c03_row33_col4, #T_e3c03_row34_col0, #T_e3c03_row34_col1, #T_e3c03_row34_col2, #T_e3c03_row34_col3, #T_e3c03_row34_col4, #T_e3c03_row35_col0, #T_e3c03_row35_col1, #T_e3c03_row35_col2, #T_e3c03_row35_col3, #T_e3c03_row35_col4, #T_e3c03_row36_col0, #T_e3c03_row36_col1, #T_e3c03_row36_col2, #T_e3c03_row36_col3, #T_e3c03_row36_col4, #T_e3c03_row37_col0, #T_e3c03_row37_col1, #T_e3c03_row37_col2, #T_e3c03_row37_col3, #T_e3c03_row37_col4, #T_e3c03_row38_col0, #T_e3c03_row38_col1, #T_e3c03_row38_col ...
